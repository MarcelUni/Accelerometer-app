# %%
# Since I can't access the file stored on my IOS device, i will manually write in the values of the results.
# The application shows the datapath and the vector3 results

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = { 'X': [0.07, 0.07, -0.61, 0.58, -0.54, 0.04, 0.08, -0.12, 0.03, -0.23],
         'Y': [-0.27, -0.35, -0.03, -0.15, -1.10, -1.00, -1.02, 0.64, 0.64, 0.28],
         'Z': [-1.05, -0.94, -1.09, -1.06, -2.56, 0.31, 0.00, -2.53, 0.51, -1.18]
       }

df = pd.DataFrame(data)
df.shape
# Out:
# (10, 3)

# %%
x = data['X']
y = data['Y']
z = data['Z']

# %%
# Putting the data into a 3D scatter plot

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(x, y, z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
